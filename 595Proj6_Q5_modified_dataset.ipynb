# %%
import numpy as np
import h5py
import matplotlib.pyplot as plt
from scipy.special import expit

# Load dataset
def load_data(train_file, test_file):
    train_data = h5py.File(train_file, 'r')
    test_data = h5py.File(test_file, 'r')
    X_train = np.array(train_data['train_set_x'][:])
    Y_train = np.array(train_data['train_set_y'][:])
    X_test = np.array(test_data['test_set_x'][:])
    Y_test = np.array(test_data['test_set_y'][:])
    return X_train, Y_train, X_test, Y_test

X_train, Y_train, X_test, Y_test = load_data('/Users/inxay/Downloads/train_catvnoncat.h5', '/Users/inxay/Downloads/test_catvnoncat.h5')

print(f"Train X shape: {X_train.shape}, Train Y shape: {Y_train.shape}")
print(f"Test X shape: {X_test.shape}, Test Y shape: {Y_test.shape}")

# Normalize data
X_train = X_train / 255.0
X_test = X_test / 255.0

# Flatten images into vectors for simpler models
X_train_flat = X_train.reshape(X_train.shape[0], -1)  # Each row is an image
X_test_flat = X_test.reshape(X_test.shape[0], -1)
Y_train = Y_train.reshape(-1, 1)  # Ensure 2D
Y_test = Y_test.reshape(-1, 1)
# Out:
# Train X shape: (209, 64, 64, 3), Train Y shape: (209,)
# Test X shape: (50, 64, 64, 3), Test Y shape: (50,)

# %%
def sigmoid(z):
    return expit(z)

def initialize_weights(dim):
    W = np.zeros((dim, 1))
    b = 0
    return W, b

def propagate(W, b, X, Y):
    m = X.shape[0]
    A = sigmoid(np.dot(X, W) + b)  
    cost = -1 / m * np.sum(Y * np.log(A + 1e-8) + (1 - Y) * np.log(1 - A + 1e-8))  # Here avoid log(0)
    dW = 1 / m * np.dot(X.T, (A - Y))
    db = 1 / m * np.sum(A - Y)
    return dW, db, cost

def optimize(W, b, X, Y, num_iterations, learning_rate):
    costs = []
    for i in range(num_iterations):
        dW, db, cost = propagate(W, b, X, Y)
        W -= learning_rate * dW
        b -= learning_rate * db
        if i % 100 == 0:
            costs.append(cost)
            print(f"Iteration {i}: Cost {cost}")
    return W, b, costs

def predict(W, b, X):
    A = sigmoid(np.dot(X, W) + b)
    return (A > 0.5).astype(int)

# %%
# Initialize weights
dim = X_train_flat.shape[1]
W, b = initialize_weights(dim)

# Train the model
W, b, costs = optimize(W, b, X_train_flat, Y_train, num_iterations=1000, learning_rate=0.01)

# Predict
Y_pred_train = predict(W, b, X_train_flat)
Y_pred_test = predict(W, b, X_test_flat)

# Calculate accuracy
train_accuracy = 100 - np.mean(np.abs(Y_pred_train - Y_train)) * 100
test_accuracy = 100 - np.mean(np.abs(Y_pred_test - Y_test)) * 100

print(f"Training Accuracy: {train_accuracy:.2f}%")
print(f"Test Accuracy: {test_accuracy:.2f}%")
# Out:
# Iteration 0: Cost 0.6931471605599454
# Iteration 100: Cost 0.8239208323558757
# Iteration 200: Cost 0.4189447384272676
# Iteration 300: Cost 0.6173496657116186
# Iteration 400: Cost 0.5221157402453612
# Iteration 500: Cost 0.3877087271105337
# Iteration 600: Cost 0.23625444230046308
# Iteration 700: Cost 0.15422212100643878
# Iteration 800: Cost 0.13532781663305668
# Iteration 900: Cost 0.12497146849839676
# Training Accuracy: 98.56%
# Test Accuracy: 70.00%

# %%
# Find misclassified indices
misclassified_indices = np.where(Y_pred_test.flatten() != Y_test.flatten())[0]

# Display 4 misclassified images
plt.figure(figsize=(10, 10))
for i, idx in enumerate(misclassified_indices[:4]):
    plt.subplot(2, 2, i + 1)
    plt.imshow(X_test[idx])
    plt.title(f"Index: {idx} (Pred: {Y_pred_test[idx][0]}, True: {Y_test[idx][0]})")
plt.show()

# %%
# Load dataset
def load_data_2(train_file):
    train_data = h5py.File(train_file, 'r')
    X = np.array(train_data['train_set_x'][:])
    Y = np.array(train_data['train_set_y'][:]) 
    return X, Y

# Load train_catvnoncat.h5
X_train_full, Y_train_full = load_data_2('/Users/inxay/Downloads/train_catvnoncat.h5')

# Split into the modified training and test datasets
new_train_indices = np.arange(165)  # First 160 + id images for training     112878395 id and last digit 5 so 160 + 5 = 165
new_test_indices = np.arange(165, 209)  # Remaining images for testing

X_train_modified = X_train_full[new_train_indices] / 255.0  # Normalize
Y_train_modified = Y_train_full[new_train_indices].reshape(-1, 1)

X_test_modified = X_train_full[new_test_indices] / 255.0  # Normalize
Y_test_modified = Y_train_full[new_test_indices].reshape(-1, 1)

# Flatten images for the model
X_train_modified = X_train_modified.reshape(X_train_modified.shape[0], -1)  # Flatten each image into a row
X_test_modified = X_test_modified.reshape(X_test_modified.shape[0], -1)    # Same for test set

# Check dimensions
print(f"Modified Training Data Shape: {X_train_modified.shape}")
print(f"Modified Test Data Shape: {X_test_modified.shape}")
# Out:
# Modified Training Data Shape: (165, 12288)
# Modified Test Data Shape: (44, 12288)

# %%
# Initialize weights
dim = X_train_modified.shape[1]  # Number of pixels per image
W, b = initialize_weights(dim)

# Train the model on the modified dataset
W, b, costs = optimize(W, b, X_train_modified, Y_train_modified, num_iterations=1000, learning_rate=0.01)

# Predict on both training and test sets
Y_pred_train_modified = predict(W, b, X_train_modified)
Y_pred_test_modified = predict(W, b, X_test_modified)

# Calculate training and test accuracies
train_accuracy_modified = 100 - np.mean(np.abs(Y_pred_train_modified - Y_train_modified)) * 100
test_accuracy_modified = 100 - np.mean(np.abs(Y_pred_test_modified - Y_test_modified)) * 100

print(f"Modified Training Accuracy: {train_accuracy_modified:.2f}%")
print(f"Modified Test Accuracy: {test_accuracy_modified:.2f}%")
# Out:
# Iteration 0: Cost 0.6931471605599454
# Iteration 100: Cost 0.3886552791097856
# Iteration 200: Cost 0.5603321894668984
# Iteration 300: Cost 0.5391101246427732
# Iteration 400: Cost 0.3760856796746633
# Iteration 500: Cost 0.1823941715603481
# Iteration 600: Cost 0.12656300891424574
# Iteration 700: Cost 0.11348480312542669
# Iteration 800: Cost 0.10367898921884625
# Iteration 900: Cost 0.09564430434346538
# Modified Training Accuracy: 100.00%
# Modified Test Accuracy: 52.27%

# %%
# Find misclassified indices
misclassified_indices_modified = np.where(Y_pred_test_modified.flatten() != Y_test_modified.flatten())[0]
print("Misclassified Indices in Modified Test Set:", misclassified_indices_modified)

# Display 4 misclassified images for examination
plt.figure(figsize=(10, 10))
for i, idx in enumerate(misclassified_indices_modified[:4]):  # Display only the first 4
    plt.subplot(2, 2, i + 1)
    plt.imshow(X_train[idx].reshape(X_train.shape[1:]), cmap='gray')  # Adjust shape if needed
    plt.title(f"Index: {idx} (Pred: {Y_pred_test_modified[idx][0]}, True: {Y_test_modified[idx][0]})")
plt.show()
# Out:
# Misclassified Indices in Modified Test Set: [ 2  4  5  6  7  8 10 12 14 18 20 23 27 30 31 32 33 35 37 39 40]
